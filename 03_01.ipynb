# %% [markdown]
# <a href="https://colab.research.google.com/github/GodHyeonG/PyTorch/blob/main/03_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **비용 함수(Cost function)**

# %% [markdown]
# **비용 함수(cost function) = 손실 함수(loss function)** = 오차 함수(error function) = 목적 함수(objective function)

# %% [markdown]
# 오차 = 실제값 - 예측값
#
# -> 오차가 음수인 경우 생김(오차의 크기 제대로 측정 X)
#
# -> (각 오차들 제곱의 합) / n = **평균제곱오차(MSE)**
#
# ![image.png](data:image/png;base64,...)
#  **,**![image.png](data:image/png;base64,...)

# %% [markdown]
# ***W***: 가중치(Weight), ***b***: 편향(bias)
#
# 평균제곱오차를 *W*와 *b*에 의한 비용함수로 재정의해보면,
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **옵티마이저(Optimizer) - 경사 하강법(Gradient Descent)**

# %% [markdown]
# 편향 *b*가 0이라고 가정한 ***y = Wx***를 기준으로 설명
#
# ![image.png](data:image/png;base64,...)
